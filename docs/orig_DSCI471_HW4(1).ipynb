# %% [markdown]
# # Build your `Deep Convolutional Generative Adversarial Network (DCGAN)` for Deep Learning on Handwritten Digits `Image generation` Task

# %% [markdown]
# ## Annotations in cell of this Notebook:
#
# <font color='red'>Read carefully the Annotations below to understand what to write in the Notebook and what to answer in the Course Shell.</font>
#
#  `##` is the python comments for assignment requirements and/or descriptions to the code below.
#
# `???` is the marker of the place that you should REPLACE with your own python code (either name of function[s], name of variable[s], expression[s], or a whole code line etc.), which should be able to be executed without errors. <strong>You may also find some inspirations from previous HomeWork assignment to write desired code for similar purpose/functionality </strong>
#
# `##-Qx: ` is the numbered identifier to indicate the question you should answer in the Course Shell for this homework. For example    `##-Q1: ` and `##-Q6: ` .
#
# [`clickable link`]() is some tip/hint resources you many refer to in addition to your learning resources from this course or your self explorations.

# %% [markdown]
# ## Task Overview
# <img src="https://miro.medium.com/max/1400/1*N3nT9AXVnsFBta2R1eEMjg.png" width="500">
# 　　　　　　　　　　　　　　　　　　　　　　　　　　　　　<strong>A Task Schema Diagram</strong>
#
# Generative Adversarial Networks (GANs) is a framework to train generative models, such as deep convolutional neural networks for generating images. GAN composed of two models which are trained simultaneously by an adversarial process. A generator model ("the artist") learns to create fake images that look real, while a discriminator model ("the art critic") learns to tell real images apart from fakes.
#
# During training, the generator progressively becomes better at creating images that look real, while the discriminator becomes better at telling them apart. The process reaches equilibrium when the discriminator can hardly distinguish real images from fakes.
#
# For a simple GAN the generator is build as a simple fully connected network. The generator of a Deep Convolutional Generative Adversarial Network (DCGAN) are mainly composes of convolution layers without max pooling with convolutional stride and transposed convolution (Fractionally-strided convolution or Deconvolution) for the downsampling and the upsampling of 2D images.
#
#
# You will conduct a `Image generation` task, by `building` a DCGAN architecture with Python to generate `fake images` from random `noise input`, that after proper `training` of the model it would look like images of `real handwritten digits`.
#
# The `TensorFlow 2.x` platform and its integrated version of `Keras API` (versus the traditional Keras Package) should be the handy tools for you to complete this task. Please take advantage of the official well supported TensorFlow & Keras [`Help Documentations`](https://www.tensorflow.org/api_docs/python/tf/keras) for correct usages of the API and functions.

# %%
## Import related Modules for TensorFlow framework and Keras API
   

## import the TensorFlow and give it alias "tf" 
import tensorflow as tf 


## import the `Keras` API from TensorFlow 
from tensorflow import keras
##-Q1: copy your composed code in the line above to answer corresponding question in the Course Shell


## import the namespace "layers" and "optimizer" of Keras from Tensorflow 
##   - use comma and exactly one space to seperate each namespace
from tensorflow.keras import layers, optimizers 
##-Q2: copy your composed code in the line above to answer corresponding question in the Course Shell


## import the Numpy package and give it alias "np" 
import numpy as np

import matplotlib.pyplot as plt

# %%
## Record the starting time of runing DCGAN project
## Create a image folder to store generated fake images for every interval during training
import os
from datetime import datetime
datetime_now = datetime.now()
print(f"DCGAN Project starts at {datetime_now}")
datetime_now = datetime_now.strftime("%Y%d%m_%H%M%S")
if os.path.exists('dcgan_fake_images'):       
    os.rename("dcgan_fake_images", f"dcgan_fake_images_{datetime_now}")    
    os.makedirs('dcgan_fake_images')
else:        
    os.makedirs('dcgan_fake_images')
# Out:
# DCGAN Project starts at 2026-05-30 14:33:49.651123

# %% [markdown]
# ## Prepare Dataset
#
# ### The Image Dataset of MNIST Handwritten Digits - Introduction

# %% [markdown]
# The [`MNIST`](http://yann.lecun.com/exdb/mnist/) database (Modified National Institute of Standards and Technology database) is a large database of handwritten digits that is widely used for training and testing Deep Learning Models.
#
# The images in the dataset contains small square images with pixels in grayscale, and each image present a real handwritten single digits between 0 and 9.
#
# The image genration task is to generate fake images out of noise inputs and have the fake images looks like a handwritten digit.

# %% [markdown]
# ### Load Data
#
# Load the MNIST dataset distributed with Keras.

# %%
## Load the MNIST data from the Keras in Tensorflow framework
mnist_data = keras.datasets.mnist
  
## We will only use the images to train the DCGAN, so use '_' to replace other variable locations
##   Since we are not trying to train model to classify into correct labels 
##   We only need to identify if a image is real or fake as 1 or 0
## replace ONLY the '???' in the code line below:
(images_train, _),(_, _) = mnist_data.load_data()

# %% [markdown]
# ###  Explore Data

# %%
## Find out the datatype, dimensions, and min/max value (i.e. value range) of the loaded data `images_train` 
## Feel free to explore all aspects that could help you understand the data

print("Datatype:", images_train.dtype)
print("Shape:", images_train.shape)
print("Dimensions:", images_train.ndim)
print("Minimum value:", images_train.min())
print("Maximum value:", images_train.max())
# ...
# Out:
# Datatype: uint8
# Shape: (60000, 28, 28)
# Dimensions: 3
# Minimum value: 0
# Maximum value: 255

# %%
## Define a function for visualizing some images
def images_show(images, dim=(1,6), figsize=(12,6), num_postfix=-1):
    plt.figure(figsize=figsize)
    for i in range(images.shape[0]):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(images[i], cmap='Greys_r', interpolation='nearest')
        plt.axis('off') 
    plt.savefig(f'dcgan_fake_images/fake_images_iter_{num_postfix:05d}.png') 
    plt.pause(0.1)

# %%
## Call the function images_show to show first 6 images in the loaded data, i.e. images_train

loaded_image_samples = images_train[:6] 
images_show(loaded_image_samples)  

##-Q3: What are the code you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the code comment)? 
# The code i filled in are image_samples = image_train[:6] and images_show(image_samples)

# %% [markdown]
# ### Preprocess data

# %%
## To faciliate the model training, we would preprocess to normalize and reshape the images

def images_preprocess(images):
    ## Normalize the input images to the range of [-1, 1] 
    images = images / 127.5 - 1
    
    ## Convert dimension of all grayscale images to be enforce to have a color channel in its dimensions
    ##   i.e. convert origianl 3D tensor (number_of_data, image_height, image_width) of `images_train`
    ##        to 4D tensor by adding the addiontal dimension as the color channel
    ##   - fill in only the number values to replace the ??? below:
    images = images.reshape(-1, 28, 28, 1).astype('float32')       
    ##-Q4: What are the number values you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 
    # the number values i filled in are -1, 28, 28, and 1 in the order of the code line.
    return images

## Use the function images_preprocess to preprocess the loaded data `images_train`  
images_preprocessed = images_preprocess(images_train) 
##-Q5: What are the code you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 
# the code i filled in is images_preprocessed = images_preprocess(images_train)

# %% [markdown]
# ### Prepare dataset

# %%
## Prepare dataset from the preprocessed image data by shuffle and batch 

## set parameter BUFFER_SIZE as the total number of images in the loaded data `images_train`
BUFFER_SIZE = images_train.shape[0]   
    
## set parameter BATCH_SIZE as 64
BATCH_SIZE = 64

## create dataset for real images 
images_data = tf.data.Dataset.from_tensor_slices(images_preprocessed)
def get_dataset_real(dataset, buffer=BUFFER_SIZE, batch=BATCH_SIZE, drop_remainder = True):
    ## Shuffle and Batch to prepare the dataset for real images
    dataset = dataset.shuffle(buffer).batch(batch, drop_remainder = drop_remainder).prefetch(1)
    return dataset

# %%
## create noises for generating fake images during the training stage
 
## use a 1D random vector as the noise input 
##   for the generator model to create one fake image later 
## Set the dimension of the vector (i.e. NOISE_SIZE) as 100 
##   i.e. the number of input 
NOISE_SIZE = 100

## create a batch of random vectors that each is in the range of [-1, 1] (as noises)  
##   i.e. random vectors for one batch
def get_noise_one_batch(batch_size=BATCH_SIZE, noise_size=NOISE_SIZE):
    noice_one_batch = np.random.uniform(-1, 1, (batch_size, noise_size))
    return noice_one_batch

# %% [markdown]
# ## Build architecture of your DCGAN model
#
# DCGAN is based on GAN, which composed of two models in neural networks:
#
# - The first model is called a **Generator** and it aims to generate new data similar to the real one. In DCGAN it would generate an unexisted image that we call fake image for this project.
#
# - The second model is named the **Discriminator** and it aims to recognize if a data is ‘real’ — belongs to the original dataset; Or if it is ‘fake’ — generated by a forger. Whose output is a binary 1 or 0.
#
#
#
# The basic building block of neural network is the layer.
# You will configure each layer of your model, then compiling the model.
#
#
#
# <br>
#
# For this task you are required to chain together layers as the architecture of the DCGAN.
#
# **Besides the layers you've already practiced and familiared with** in the **previous assignments** (E.g. **Dense, Convolutional, Flatten** layers etc.),
#
# the following  [**new types of layers**](https://www.tensorflow.org/api_docs/python/tf/keras/layers) might also needed in this task. Their API references listed below (as how to apply their corresponding **parameters** to configure the layer) might provide you more inspirations.
#
# - [Reshape](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Reshape)
#
# - [Conv2DTranspose](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2DTranspose)
#
# - [LeakyReLU](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LeakyReLU)

# %% [markdown]
# ### Build the Generator Model
#
#
# This Generator Model will receive noise vectors as inputs, and generated fake images as output;
#
# A vector in the inputs would be converted and upsampled several times until reaching the same size of a real image.

# %%
## Build a Generator model by stacking keras layers sequentially  
 
generator = keras.Sequential ([        
##-Q6: What is the function name that you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 
# I used keras.Sequential to build the generator model by stacking keras layers sequentially.
    ## *** READ *VERY CAREFULLY* Below What is DESCRIBED and REQUIRED to be FULFILLED *** 
    
    ## Apply a fully-connected layer WITH bias, 
    ##   to receive and feature mapping the input, i.e. the noice vector
    layers.Dense(7*7*128, input_shape=(NOISE_SIZE,), use_bias=True),   
    ##-Q7: What are the code that you should put in place of the ??? in the above code line to fulfill its purpose of design (requirements in the comment)? 
    # I used layers.Dense to apply a fully-connected layer, 7*7*128 as the number of units, input_shape=(NOISE_SIZE,) to specify the input shape, and use_bias=True to apply bias in the layer.
    ## Add a Reshape layer to change the output from previous 1D input layer into 3D 
    ##   which has 7X7 as size of generated 2D latent image 
    ##   with 128 features in the 3rd dimension
    layers.Reshape([7, 7, 128]), 
    
    ## Build a transposed convolution layer WITHOUT bias 
    ##      to do inversed convolution as a way to do learnable Upsampling;
    ##   which has number of filters that equals to HALF of the 
    ##      feature dimension of the output from previous layer; 
    ##   5 X 5 as the kernel size;
    ##   stride step as 2 for all of its spatial dimensions; and 
    ##   padding with zeros evenly to the surroundings of the input. 
    layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False),
    ##-Q8: What are the code that you should put in place of the ??? in the above code line 
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    # I used layers.Conv2DTranspose to build a transposed convolution layer, 64 as the number of filters, (5, 5) as the kernel size, strides=(2, 2) for stride step as 2 for all of its spatial dimensions, padding='same' for padding with zeros evenly to the surroundings of the input, and use_bias=False to build the layer without bias.
    ##-Q9: After upsampling by transposed convolution layer with the required parameter configurations,
    ##      What is the dimension of the 2D latent image that was 7X7 output from previous layer? 
 
     # the dimension of the 2D latent image after upsampling by the transposed convolution layer is 14X14, since the stride step is 2 for all of its spatial dimensions.
    
    ## Add a Batch Normalization layer which would stabilize the learning procedure
    ##   by standardizing activations from the prior layer to 
    ##   have normal distribution with the mean value of 0 and unit variance  
    layers.BatchNormalization(),  
    
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    ##   which still allow some negative value to pass through the network for continue learning
    ##   even if it is negative, by multiply which with alpha     
    layers.LeakyReLU(alpha=0.2), 
    
    
    
    ## Build a transposed convolution layer WITHOUT bias;
    ##   which has number of filters that equals to HALF of the 
    ##      feature dimension of the output from previous layer; 
    ##   3 X 3 as the kernel size; 
    ##   stride step as 2 for all of its spatial dimensions; and 
    ##   padding with zeros evenly to the surroundings of the input. 
    ## ???.???(???, (???, ???), strides=(???, ???), padding='???', use_bias=???),
    layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding='same', use_bias=False),
    ##-Q10: What is the code line that you should put in place of the ??? line in the above  
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    ##   - use exactly only one space when needed, use only exactly one space after comma when comma is needed
    # I used layers.Conv2DTranspose to build a transposed convolution layer, 32 as the number of filters, (3, 3) as the kernel size, strides=(2, 2) for stride step as 2 for all of its spatial dimensions, padding='same' for padding with zeros evenly to the surroundings of the input, and use_bias=False to build the layer without bias.
    ##- Think about : After upsampling by this transposed convolution layer with the required parameter configurations,
    ##      What is the dimension of the 2D latent image that was output from its previous layer? 
 
    
    ## Add a Batch Normalization layer  
    layers.BatchNormalization(),
    
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    layers.LeakyReLU(alpha=0.2),
       
    
    ## Build a transposed convolution layer WITHOUT bias;
    ##   which has a number of filters 
    ##      that would make the output, i.e. the generated image, 
    ##      to have only 1 feature dimension, i.e. 1 color channel
    ##   3 X 3 as the kernel size; 
    ##   SET stride step as a PROPER number 
    ##      that would make the output, i.e. the generated image, 
    ##      to have its first 2 dimensions (i.e. height and width), same as the loaded mnist real image
    ##      i.e. the generated image in same image size as the real image.        
    ##   padding with zeros evenly to the surroundings of the input;
    ##   and CHOOSE an activation function that could make 
    ##      the range of output fake image's pixel values the SAME as preprocessed real iamge 
    ##      i.e. a range in [-1, 1]  
    layers.Conv2DTranspose(1, (3, 3), strides=(1, 1), padding='same', use_bias=False, activation='tanh'),
    ##-Q11: What are the code that you have put in place of the 1st,2nd,3rd and 6th ??? in the above code line 
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    # layers.Conv2DTranspose(1, (3, 3), strides=(2, 2), padding='same', use_bias=False, activation='tanh'),
    ## A following Reshape layer is to make sure the output fake image has same dimensions as the real images.
    ##   - if error occurs (dimension not match) it may suggest you to check if the previous layer configuration (e.g. strides) is correct
    layers.Reshape([28, 28, 1])
])

## suggestion: take a look at your model's architecture by printing it out 
##   and think it through about how the transposed convolution generate the final image through upsampling
# Out:
# c:\Users\sshab\Documents\School\DSCI471\DSCI_471_Homework_4\.venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\sshab\Documents\School\DSCI471\DSCI_471_Homework_4\.venv\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# ### Build the Discriminator Model
#
#
# This Discriminator Model in DCGAN is basically a normal **CNN*** (So you could **recall how you build your CNN model in previous assignment**) that can be trained for binary classification, to identify real or fake images.
#
# The Discriminator Model will receive images as inputs, and binary values 1 or 0 as the outputs, representing the classification of the input images to be real or fake.

# %%
## set the input dimension for Discriminator Model
##   to the image shape in the tensor format (image_height, image_width, color_channels)
image_dim =(28, 28, 1)


# Build a tf.keras.Sequential model by stacking layers

discriminator = keras.Sequential([      
    ## Build a Convolutional layer that 
    ##   `input_shape` equal to the image dimention,  
    ##   has 64 filters, 
    ##   5 X 5 as the kernel size, 
    ##   stride step as 2,and 
    ##   padding with zeros evenly to the surroundings of the input.     
    ## - ref: ???.???(???, (???, ???), strides=(???, ???), input_shape=image_dim, padding='???'),
    layers.Conv2D(64, (5, 5), strides=(2, 2), input_shape=image_dim, padding='same'),

    
    ##-Q12: What is the code line that you should put in place of the ??? line in the above  
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    ##   - use exactly only one space when needed, use only exactly one space after comma when comma is needed
    
    # I used layers.Conv2D to build a convolutional layer, 64 as the number of filters, (5, 5) as the kernel size, strides=(2, 2) for stride step as 2 for all of its spatial dimensions, input_shape=image_dim to specify the input shape, and padding='same' for padding with zeros evenly to the surroundings of the input.
    
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    layers.LeakyReLU(alpha=0.2), 
    
    ## Add a Droupout layer to reduce overfitting     
    ##   and set the rate to be 0.3 of the input units for dropping out  
    layers.Dropout(0.3),    
    
    
    ## Build a Convolutional layer that   
    ##   has 128 filters, 
    ##   3 X 3 as the kernel size, 
    ##   stride step as 2,and 
    ##   padding with zeros evenly to the surroundings of the input.
    layers.Conv2D(128, (3, 3), strides=(2, 2), padding='same'), 


    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    layers.LeakyReLU(alpha=0.2), 
 
    
    ## Add a Droupout layer to reduce overfitting     
    ##   and set the rate to be 0.3 of the input units for dropping out  
    layers.Dropout(0.3),    
    
    
    ## Build a Convolutional layer that   
    ##   has 256 filters, 
    ##   3 X 3 as the kernel size, 
    ##   stride step as 2,and 
    ##   padding with zeros evenly to the surroundings of the input.
    ## Add a layer of Leaky ReLU activation function with alpha being 0.2, 
    ## Add a Droupout layer to reduce overfitting     
    ##   and set the rate to be 0.3 of the input units for dropping out  
    layers.Conv2D(256, (3, 3), strides=(2, 2), padding='same'),      
    layers.LeakyReLU(alpha=0.2),     
    layers.Dropout(0.3),        
    
    
    ## Biuld A Flatten layer to flatten the input  
    layers.Flatten(),    
    ##-Q13: What is the code line that you should put in place of the ??? line in the above  
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    ##   - use exactly only one space when needed, use only exactly one space after comma when comma is needed
    # I used layers.Flatten to build a Flatten layer to flatten the input.
    
    ## Apply a `full-connected` output layer 
    ##   with a unit number that can output a binary value;
    ##   - choose a proper activation function 
    ##      for this goal of *binary output* (binary classification task)    
    layers.Dense(units=1, activation='sigmoid')    
    ##-Q14: What are the code that you should put in place of the ??? in the above code line 
    ##     to fully fulfill its purpose of design (requirements in its above comments)? 
    
    # The code I used is layers.Dense(units=1, activation='sigmoid') to apply a full-connected output layer with 1 unit to output a binary value, and use 'sigmoid' as the activation function for this binary classification task.
])


## suggestion: take a look at your model's architecture by printing it out 
##   and think it through as well as compare with your previous CNN model
# Out:
# c:\Users\sshab\Documents\School\DSCI471\DSCI_471_Homework_4\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ##### Compile Discriminator Model first
#
# Before the model is ready for training, it needs a few more settings. These are to be added during the [model's compiling](https://www.tensorflow.org/api_docs/python/tf/keras/Model) step:
#
# - [Optimizer](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) : This is how the model is updated based on the data it sees and its loss function.
# - [Loss function](https://www.tensorflow.org/api_docs/python/tf/keras/losses) : This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.

# %% [markdown]
# Choose your optimizer:

# %%
## Set your optimizer for compiling the models later
## Select an optimizer that implements the Adam algorithm, 
##   and validate to decide a proper learning rate for your model 

# discriminator_optimizer = optimizers.Adam(learning_rate=0.0002, beta_1=0.5)
my_optimizer = optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

dcgan_optimizer = optimizers.Adam(learning_rate=0.0002, beta_1=0.5)

##-Q15: What are the code line that you should put in place of the ??? in the above code line 
##     to fully fulfill its purpose of design (requirements in its above comments)? 

# I used optimizers.Adam(learning_rate=0.0002, beta_1=0.5) to select an optimizer that implements the Adam algorithm, and set the learning rate to be 0.0002 and beta_1 to be 0.5 for my model.

# %% [markdown]
# Compile Discriminator Model:

# %%
## Compile the Discriminator model with your chosen optimizer, 
##   and use Binary cross-entropy as losses, 
discriminator.compile(
        optimizer=my_optimizer,
        loss=keras.losses.BinaryCrossentropy()
       )                     

##-Q16: What are the code that you should put in place of the ??? in the above code line 
##     to fully fulfill its purpose of design (requirements in its above comments)? 

# I used discriminator.compile(optimizer=my_optimizer, loss=keras.losses.BinaryCrossentropy()) to compile the Discriminator model with my chosen optimizer, and use Binary cross-entropy as losses.
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
#
# ### Build the DCGAN Model
#
#
# Build the DCGAN by concatenating the Generator and Discriminator into one sequential.
#
# The DCGAN Model will receive noise vectors as inputs, and a binary values 1 or 0 as the outputs, representing the classification of the input images to be real or fake.
#
# The Generator model is only concerned with the discriminator’s performance on fake examples. Therefore, we will mark all of the layers in the Discriminator as not trainable when it is part of the GAN model so that they can not be updated and overtrained on fake examples.

# %%
## make discriminator not-trainable as of now
discriminator.trainable = False

## Combine both Generator and Discriminator Models
dcgan = keras.Sequential([     
    generator,   
    discriminator      
])

dcgan.summary()

##-Q17: What is the `total number` of params (i.e. weights) , 
##      including the Non-trainable params e.g. from the Discriminator part, 
##      in the whole DCGAN Model build above?
##      be careful in the calculations, For example. with or without bias. 

# The total number of params in the whole DCGAN Model is 1,232,161, including the Non-trainable params from the Discriminator part.
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 28, 28, 1)      │       857,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 1)              │       374,785 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,232,161 (4.70 MB)
#  Trainable params: 857,184 (3.27 MB)
#  Non-trainable params: 374,977 (1.43 MB)

# %% [markdown]
# ##### Compile DCGAN
#
# And then compile the whole DCGAN

# %%
## Compile the DCGAN model as a whole with your chosen optimizer, 
##   and use Binary cross-entropy as losses, 
dcgan.compile(optimizer=dcgan_optimizer,
              loss=keras.losses.BinaryCrossentropy()
             )

# %% [markdown]
# ## Train the model
#
# Train the DCGAN to improve the ability of generating good fake images by the Generator.

# %% [markdown]
# Prepare 6 random noice vectors, to check and compare how the generated fake images on same 6 inputs are improved over the training procedure.

# %%
## create random noice inputs to checking the corresponding generated fake images 

## create random noise inputs of 6
##    which will be later used for comparison of the generated images
##    on these same sample noises during the training 
noise_inputs_check = get_noise_one_batch(6)  
## generate the initial output images before training
images_outputs_check = generator.predict(noise_inputs_check)

## Show the 6 generated images: 
images_show(images_outputs_check, num_postfix=-1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %% [markdown]
# ##### Train Discriminator Model and DCGAN Model
#
# In each training loop, the Discriminator Model is first trained to better classify real images (drawn from the real image dataset ) and fakes images (produced by the Generator Model based on random noice as input).
#
# The Discriminator in DCGAN was first marked as not trainable to train only weights of layers in the Generator of DCGAN Model to help better generate fake images like real.

# %%
## Define training parameters  

## set epochs size/count 
##  it is assigned a initial value 1 TEMPORARILY, you need to replace it to your tunned value eventually.
EPOCHS = 10   ### 1 is a temporary value that you need to update before submitting 


## Calculated the Number of batches based on the loaded data `images_train`  and the size of a batch
BATCHS = np.floor(BUFFER_SIZE/BATCH_SIZE).astype('int')

## Set the interval as 300 
##   to show generated images by the Generator trained so far in the training procedure
##   on the same 6 noise vector inputs.
##   i.e. Display every 300 iterations the 6 generated fake images as training keeps improving it
iter_interval = 300

## Define binary labels that represent real and fake outputs for each batch training
labels_real = np.ones((BATCH_SIZE, 1))
labels_fake = np.zeros((BATCH_SIZE, 1))

# %% [markdown]
# ###  <font color='red'>NOTICE:</font>
#
# <font color='red'>Depending on your EPOCHS count, your computer computation capability, etc. the training procedure could take HOURS </font>
#
# You could temporarily replace the variable name `EPOCHS` in the below code cell to be a small value for testing.  After tunning all other parameters above this cell, you can then replace that small value back to the original variable name `EPOCHS`, so your setting on the `EPOCHS` in the above code cell could take effect.
#
# For example, if you replace　　`for epoch in range(0, EPOCHS):`　　to be　 　`for epoch in range(0, 1):`
#
# and execute the below code cell, the DCGAN will only be trained for 1 epoch for all the batches, and stop there.
#
# <br>
#
# After that you can keep manually changing it to be 　　`for epoch in range(1, 2):`
#
# and execute the below code cell again (without needing to restart the whole notebook), the DCGAN will keep beeing trained for the 2nd epoch, and the training will continue based on the parameters already learned from the 1st epoch.
#
# As long as your computer, Jupyter notebook local server, and this .ipynb, are not colsed, you should be able to keep on the training procesure, instead of training all over again.
#
# For example if you want to run the 3rd epoch, then keep manually change it to be 　　 `for epoch in range(2, 3):`
#
# then the model will continued to be trained upon the parameters learned from the 2nd epoch
#
# <br>
#
# This way of manually start the next epoch round could let you have more controls on the tunning or debugging, and have a better idea how many epochs your model would eventually need. 　Note re-run the below cell will overwrite the output so you won't be able to see the image plots generated from previous epoch, but you can always go into your image subfolder to inspect.
#
# After you tunned to decide a satisfied epoch count (as well as other parameters), then you can assign that value to the variable `EPOCHS` in the above code cell, and change the bellow cell back to `for epoch in range(0, EPOCHS):`, and save the .ipynb before colse and halt it, then reopen the .ipynb to have a full run-from-beginning, to complete this assignment for the submission.

# %%
## Start Model Training in the iterations

## Record the Starting time of runing DCGAN training
datetime_now = datetime.now()
print(f"~~~ DCGAN training starting at {datetime_now} \n\n ")  

for epoch in range(0, EPOCHS): 
    ## generate new dataset of real images for each epoch
    real_dataset = get_dataset_real(images_data)
    
    for batch, images_real in enumerate(real_dataset):
        
        ## Train Discriminator seperately:
        
        ## Make Discriminator Trainable for now
        ##   i.e.set the Discriminator Model trainable to be trained on real and fake images
        discriminator.trainable = True     
        
        ## Batch Train Discriminator Model on a batch of real images with them labeled as real 
        d_loss_real = discriminator.train_on_batch(images_real, labels_real)
        
        ## create a random noise batch inputs and pass which into the Generator to generate fake images
        noise_inputs = get_noise_one_batch()
        images_fake = generator.predict(noise_inputs)
                          
        ## Train Discriminator Model on a batch of fake images with them labeled as fake 
        d_loss_fake = discriminator.train_on_batch(images_fake, labels_fake)
                          
            
        ## Train DCGAN model     
        
        ## Make Discriminator Not-trainable for now
        ##   i.e. set the Discriminator Model NOT trainable 
        ##        to only update layer weights of Generator            
        discriminator.trainable = False  
        ##-Q18: What is the code line that you should put in place of the ??? in the above line 
        ##     to fully fulfill its purpose of design (requirements in its above comments)? 
        # I used discriminator.trainable = False to make the Discriminator Model NOT trainable, to only update layer weights of Generator.
        ## create a random noise batch inputs and pass which into the DCGAN later
        noise_inputs = get_noise_one_batch()
        
        ## Batch Train DCGAN Model on a batch of noise inputs with them labeled as real 
        ##   to fool the Discriminator with the fake images generated by Generator but labeled as real
        dcg_loss = dcgan.train_on_batch(noise_inputs, labels_real) 
        ##-Q19: What is the code line that you should put in place of the ??? in the above line 
        ##     to fully fulfill its purpose of design (requirements in its above comments)? 
        # I used dcgan.train_on_batch(noise_inputs, labels_real) to Batch Train DCGAN Model on a batch of noise inputs with them labeled as real to fool the Discriminator with the fake images generated by Generator but labeled as real.
        ## Print training progress with model losses  on the intervals  
        ##   and Show fake images generated on same 6 noise inputs 
        ##            which are also saved in the folder for comparison later
        iteration = (epoch * BATCHS) + (batch + 1)  

        if iteration % 5 == 0:
            print(f"=== Iter: {iteration} : d_loss_real: {d_loss_real:.9f}, d_loss_fake: {d_loss_fake:.9f}, dcg_loss: {dcg_loss:.9f} - in Epoch {epoch + 1}/{EPOCHS} - Batch {batch+1}/{BATCHS}")

        if iteration % iter_interval == 0: 
            images_check = generator.predict(noise_inputs_check)
            images_show(images_check, num_postfix=iteration)
            print("*** time now: ", datetime.now()) 
            
## Record the Ending time of runing DCGAN training
datetime_now = datetime.now()
print(f"\n\n ~~~ DCGAN trainging ends at {datetime_now}")
# Out:
# ~~~ DCGAN training starting at 2026-05-30 14:33:50.669578
#
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 5 : d_loss_real: 0.590249658, d_loss_fake: 0.601392865, dcg_loss: 0.587520778 - in Epoch 1/10 - Batch 5/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 10 : d_loss_real: 0.495668799, d_loss_fake: 0.506433010, dcg_loss: 0.466487557 - in Epoch 1/10 - Batch 10/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 15 : d_loss_real: 0.450190336, d_loss_fake: 0.458300024, dcg_loss: 0.391749054 - in Epoch 1/10 - Batch 15/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 20 : d_loss_real: 0.424110860, d_loss_fake: 0.430404812, dcg_loss: 0.333880723 - in Epoch 1/10 - Batch 20/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 25 : d_loss_real: 0.406036168, d_loss_fake: 0.410552204, dcg_loss: 0.283852696 - in Epoch 1/10 - Batch 25/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 30 : d_loss_real: 0.388132840, d_loss_fake: 0.390075386, dcg_loss: 0.247274533 - in Epoch 1/10 - Batch 30/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 35 : d_loss_real: 0.362236232, d_loss_fake: 0.360620588, dcg_loss: 0.221429020 - in Epoch 1/10 - Batch 35/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 40 : d_loss_real: 0.327091545, d_loss_fake: 0.323894113, dcg_loss: 0.200997636 - in Epoch 1/10 - Batch 40/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 45 : d_loss_real: 0.293189049, d_loss_fake: 0.290229380, dcg_loss: 0.182712659 - in Epoch 1/10 - Batch 45/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 50 : d_loss_real: 0.264630824, d_loss_fake: 0.262118340, dcg_loss: 0.166882902 - in Epoch 1/10 - Batch 50/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 55 : d_loss_real: 0.240883380, d_loss_fake: 0.238764361, dcg_loss: 0.152632102 - in Epoch 1/10 - Batch 55/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 60 : d_loss_real: 0.220953807, d_loss_fake: 0.219160601, dcg_loss: 0.140399292 - in Epoch 1/10 - Batch 60/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 65 : d_loss_real: 0.204033509, d_loss_fake: 0.202496454, dcg_loss: 0.129915342 - in Epoch 1/10 - Batch 65/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 70 : d_loss_real: 0.189500973, d_loss_fake: 0.188169390, dcg_loss: 0.120857917 - in Epoch 1/10 - Batch 70/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 75 : d_loss_real: 0.176888213, d_loss_fake: 0.175726086, dcg_loss: 0.112993225 - in Epoch 1/10 - Batch 75/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 80 : d_loss_real: 0.165840954, d_loss_fake: 0.164816603, dcg_loss: 0.106084868 - in Epoch 1/10 - Batch 80/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 85 : d_loss_real: 0.156088457, d_loss_fake: 0.155179992, dcg_loss: 0.099954002 - in Epoch 1/10 - Batch 85/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 90 : d_loss_real: 0.147417992, d_loss_fake: 0.146607444, dcg_loss: 0.094494671 - in Epoch 1/10 - Batch 90/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 95 : d_loss_real: 0.139659807, d_loss_fake: 0.138931319, dcg_loss: 0.089609809 - in Epoch 1/10 - Batch 95/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 100 : d_loss_real: 0.132674918, d_loss_fake: 0.132016957, dcg_loss: 0.085193589 - in Epoch 1/10 - Batch 100/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 105 : d_loss_real: 0.126354903, d_loss_fake: 0.125758022, dcg_loss: 0.081196941 - in Epoch 1/10 - Batch 105/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 110 : d_loss_real: 0.120609403, d_loss_fake: 0.120065488, dcg_loss: 0.077565104 - in Epoch 1/10 - Batch 110/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 115 : d_loss_real: 0.115363680, d_loss_fake: 0.114865392, dcg_loss: 0.074247852 - in Epoch 1/10 - Batch 115/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 120 : d_loss_real: 0.110554710, d_loss_fake: 0.110097498, dcg_loss: 0.071211182 - in Epoch 1/10 - Batch 120/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 125 : d_loss_real: 0.106131539, d_loss_fake: 0.105709985, dcg_loss: 0.068407282 - in Epoch 1/10 - Batch 125/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 130 : d_loss_real: 0.102049522, d_loss_fake: 0.101659603, dcg_loss: 0.065824315 - in Epoch 1/10 - Batch 130/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 135 : d_loss_real: 0.098269738, d_loss_fake: 0.097908333, dcg_loss: 0.063423626 - in Epoch 1/10 - Batch 135/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 140 : d_loss_real: 0.094759889, d_loss_fake: 0.094423577, dcg_loss: 0.061194163 - in Epoch 1/10 - Batch 140/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 145 : d_loss_real: 0.091492534, d_loss_fake: 0.091179095, dcg_loss: 0.059110761 - in Epoch 1/10 - Batch 145/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 150 : d_loss_real: 0.088444032, d_loss_fake: 0.088151045, dcg_loss: 0.057180226 - in Epoch 1/10 - Batch 150/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 155 : d_loss_real: 0.085592031, d_loss_fake: 0.085317560, dcg_loss: 0.055368934 - in Epoch 1/10 - Batch 155/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 160 : d_loss_real: 0.082918942, d_loss_fake: 0.082661465, dcg_loss: 0.053671144 - in Epoch 1/10 - Batch 160/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 165 : d_loss_real: 0.080407649, d_loss_fake: 0.080165498, dcg_loss: 0.052076064 - in Epoch 1/10 - Batch 165/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 170 : d_loss_real: 0.078045577, d_loss_fake: 0.077817731, dcg_loss: 0.050580565 - in Epoch 1/10 - Batch 170/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 175 : d_loss_real: 0.075818516, d_loss_fake: 0.075603560, dcg_loss: 0.049166445 - in Epoch 1/10 - Batch 175/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 180 : d_loss_real: 0.073715754, d_loss_fake: 0.073512912, dcg_loss: 0.047829967 - in Epoch 1/10 - Batch 180/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 185 : d_loss_real: 0.071728021, d_loss_fake: 0.071535684, dcg_loss: 0.046572454 - in Epoch 1/10 - Batch 185/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 190 : d_loss_real: 0.069845036, d_loss_fake: 0.069663048, dcg_loss: 0.045382842 - in Epoch 1/10 - Batch 190/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 195 : d_loss_real: 0.068059430, d_loss_fake: 0.067886576, dcg_loss: 0.044252615 - in Epoch 1/10 - Batch 195/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 200 : d_loss_real: 0.066364340, d_loss_fake: 0.066200100, dcg_loss: 0.043184038 - in Epoch 1/10 - Batch 200/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 205 : d_loss_real: 0.064752825, d_loss_fake: 0.064596459, dcg_loss: 0.042183854 - in Epoch 1/10 - Batch 205/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 210 : d_loss_real: 0.063221395, d_loss_fake: 0.063072398, dcg_loss: 0.041224442 - in Epoch 1/10 - Batch 210/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 215 : d_loss_real: 0.061758056, d_loss_fake: 0.061616600, dcg_loss: 0.040337306 - in Epoch 1/10 - Batch 215/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 220 : d_loss_real: 0.060364824, d_loss_fake: 0.060229741, dcg_loss: 0.039474700 - in Epoch 1/10 - Batch 220/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 225 : d_loss_real: 0.059034657, d_loss_fake: 0.058905937, dcg_loss: 0.038663045 - in Epoch 1/10 - Batch 225/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 230 : d_loss_real: 0.057789739, d_loss_fake: 0.064716019, dcg_loss: 0.163131908 - in Epoch 1/10 - Batch 230/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 235 : d_loss_real: 0.144130215, d_loss_fake: 0.144253254, dcg_loss: 0.163210243 - in Epoch 1/10 - Batch 235/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 240 : d_loss_real: 0.142895177, d_loss_fake: 0.142775595, dcg_loss: 0.170275107 - in Epoch 1/10 - Batch 240/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 245 : d_loss_real: 0.140985563, d_loss_fake: 0.140814051, dcg_loss: 0.173333332 - in Epoch 1/10 - Batch 245/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 250 : d_loss_real: 0.138861537, d_loss_fake: 0.138667762, dcg_loss: 0.173615918 - in Epoch 1/10 - Batch 250/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 255 : d_loss_real: 0.136717290, d_loss_fake: 0.136505008, dcg_loss: 0.172499046 - in Epoch 1/10 - Batch 255/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 260 : d_loss_real: 0.134549528, d_loss_fake: 0.134342834, dcg_loss: 0.170875505 - in Epoch 1/10 - Batch 260/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 265 : d_loss_real: 0.132407561, d_loss_fake: 0.132208586, dcg_loss: 0.168916523 - in Epoch 1/10 - Batch 265/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 270 : d_loss_real: 0.130345687, d_loss_fake: 0.130150676, dcg_loss: 0.167014837 - in Epoch 1/10 - Batch 270/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 275 : d_loss_real: 0.128358737, d_loss_fake: 0.128171667, dcg_loss: 0.165199712 - in Epoch 1/10 - Batch 275/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 280 : d_loss_real: 0.126470387, d_loss_fake: 0.126285553, dcg_loss: 0.163296223 - in Epoch 1/10 - Batch 280/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 285 : d_loss_real: 0.124614641, d_loss_fake: 0.124445252, dcg_loss: 0.161324888 - in Epoch 1/10 - Batch 285/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 290 : d_loss_real: 0.122815236, d_loss_fake: 0.122644253, dcg_loss: 0.159559146 - in Epoch 1/10 - Batch 290/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 295 : d_loss_real: 0.121141456, d_loss_fake: 0.120974787, dcg_loss: 0.157776445 - in Epoch 1/10 - Batch 295/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 300 : d_loss_real: 0.119515419, d_loss_fake: 0.119365022, dcg_loss: 0.156058222 - in Epoch 1/10 - Batch 300/937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# *** time now:  2026-05-30 14:34:14.934452
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 305 : d_loss_real: 0.117911831, d_loss_fake: 0.117764585, dcg_loss: 0.154415160 - in Epoch 1/10 - Batch 305/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 310 : d_loss_real: 0.116377354, d_loss_fake: 0.116235644, dcg_loss: 0.152858123 - in Epoch 1/10 - Batch 310/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 315 : d_loss_real: 0.114909790, d_loss_fake: 0.114755347, dcg_loss: 0.151492164 - in Epoch 1/10 - Batch 315/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 320 : d_loss_real: 0.113488607, d_loss_fake: 0.113385931, dcg_loss: 0.150277376 - in Epoch 1/10 - Batch 320/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 325 : d_loss_real: 0.112476073, d_loss_fake: 0.112410724, dcg_loss: 0.150151372 - in Epoch 1/10 - Batch 325/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 330 : d_loss_real: 0.127577111, d_loss_fake: 0.127413601, dcg_loss: 0.158976153 - in Epoch 1/10 - Batch 330/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 335 : d_loss_real: 0.133405313, d_loss_fake: 0.133496478, dcg_loss: 0.161853582 - in Epoch 1/10 - Batch 335/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 340 : d_loss_real: 0.134784177, d_loss_fake: 0.134786144, dcg_loss: 0.166198656 - in Epoch 1/10 - Batch 340/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 345 : d_loss_real: 0.144775122, d_loss_fake: 0.144891232, dcg_loss: 0.178623572 - in Epoch 1/10 - Batch 345/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 350 : d_loss_real: 0.149151400, d_loss_fake: 0.149601802, dcg_loss: 0.183988497 - in Epoch 1/10 - Batch 350/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# === Iter: 355 : d_loss_real: 0.153400883, d_loss_fake: 0.154104576, dcg_loss: 0.193638012 - in Epoch 1/10 - Batch 355/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 360 : d_loss_real: 0.160563037, d_loss_fake: 0.161526367, dcg_loss: 0.203135595 - in Epoch 1/10 - Batch 360/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 365 : d_loss_real: 0.166302577, d_loss_fake: 0.166863412, dcg_loss: 0.212046042 - in Epoch 1/10 - Batch 365/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 370 : d_loss_real: 0.172587365, d_loss_fake: 0.173203975, dcg_loss: 0.221064389 - in Epoch 1/10 - Batch 370/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 375 : d_loss_real: 0.180648729, d_loss_fake: 0.182012141, dcg_loss: 0.228947505 - in Epoch 1/10 - Batch 375/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 380 : d_loss_real: 0.188448966, d_loss_fake: 0.189185917, dcg_loss: 0.237142116 - in Epoch 1/10 - Batch 380/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 385 : d_loss_real: 0.194862887, d_loss_fake: 0.195551649, dcg_loss: 0.244319007 - in Epoch 1/10 - Batch 385/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 390 : d_loss_real: 0.200945348, d_loss_fake: 0.201651007, dcg_loss: 0.251122326 - in Epoch 1/10 - Batch 390/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 395 : d_loss_real: 0.206605896, d_loss_fake: 0.207120791, dcg_loss: 0.258175284 - in Epoch 1/10 - Batch 395/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 400 : d_loss_real: 0.212649271, d_loss_fake: 0.213264212, dcg_loss: 0.265643805 - in Epoch 1/10 - Batch 400/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 405 : d_loss_real: 0.219056547, d_loss_fake: 0.219800979, dcg_loss: 0.272279918 - in Epoch 1/10 - Batch 405/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 410 : d_loss_real: 0.225219041, d_loss_fake: 0.225854918, dcg_loss: 0.278188467 - in Epoch 1/10 - Batch 410/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 415 : d_loss_real: 0.231224984, d_loss_fake: 0.231835797, dcg_loss: 0.283732951 - in Epoch 1/10 - Batch 415/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 420 : d_loss_real: 0.237279028, d_loss_fake: 0.237933204, dcg_loss: 0.288643420 - in Epoch 1/10 - Batch 420/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 425 : d_loss_real: 0.242974877, d_loss_fake: 0.243586242, dcg_loss: 0.293742836 - in Epoch 1/10 - Batch 425/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 430 : d_loss_real: 0.248599187, d_loss_fake: 0.249207079, dcg_loss: 0.298797399 - in Epoch 1/10 - Batch 430/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 435 : d_loss_real: 0.253894717, d_loss_fake: 0.254445493, dcg_loss: 0.304246187 - in Epoch 1/10 - Batch 435/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 440 : d_loss_real: 0.258865714, d_loss_fake: 0.259383053, dcg_loss: 0.309828311 - in Epoch 1/10 - Batch 440/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 445 : d_loss_real: 0.263648927, d_loss_fake: 0.264144450, dcg_loss: 0.315344006 - in Epoch 1/10 - Batch 445/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 450 : d_loss_real: 0.268344313, d_loss_fake: 0.268870860, dcg_loss: 0.320624739 - in Epoch 1/10 - Batch 450/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 455 : d_loss_real: 0.272940427, d_loss_fake: 0.273409843, dcg_loss: 0.325873077 - in Epoch 1/10 - Batch 455/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 460 : d_loss_real: 0.277315468, d_loss_fake: 0.277787507, dcg_loss: 0.331193298 - in Epoch 1/10 - Batch 460/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 465 : d_loss_real: 0.281673431, d_loss_fake: 0.282159269, dcg_loss: 0.335934132 - in Epoch 1/10 - Batch 465/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 470 : d_loss_real: 0.286306530, d_loss_fake: 0.286775976, dcg_loss: 0.340692014 - in Epoch 1/10 - Batch 470/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 475 : d_loss_real: 0.290964186, d_loss_fake: 0.291457385, dcg_loss: 0.344593495 - in Epoch 1/10 - Batch 475/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 480 : d_loss_real: 0.295509249, d_loss_fake: 0.295995504, dcg_loss: 0.348455369 - in Epoch 1/10 - Batch 480/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 485 : d_loss_real: 0.300174952, d_loss_fake: 0.300724030, dcg_loss: 0.351948231 - in Epoch 1/10 - Batch 485/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 490 : d_loss_real: 0.304728806, d_loss_fake: 0.305215687, dcg_loss: 0.355781168 - in Epoch 1/10 - Batch 490/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 495 : d_loss_real: 0.309338927, d_loss_fake: 0.309824109, dcg_loss: 0.359185308 - in Epoch 1/10 - Batch 495/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 500 : d_loss_real: 0.313738942, d_loss_fake: 0.314177275, dcg_loss: 0.362793714 - in Epoch 1/10 - Batch 500/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 505 : d_loss_real: 0.317878008, d_loss_fake: 0.318269968, dcg_loss: 0.366390854 - in Epoch 1/10 - Batch 505/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 510 : d_loss_real: 0.321674407, d_loss_fake: 0.322059661, dcg_loss: 0.370092452 - in Epoch 1/10 - Batch 510/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 515 : d_loss_real: 0.325460434, d_loss_fake: 0.325841993, dcg_loss: 0.373770565 - in Epoch 1/10 - Batch 515/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 520 : d_loss_real: 0.329072088, d_loss_fake: 0.329393506, dcg_loss: 0.377442747 - in Epoch 1/10 - Batch 520/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 525 : d_loss_real: 0.332533658, d_loss_fake: 0.332884789, dcg_loss: 0.381291986 - in Epoch 1/10 - Batch 525/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 530 : d_loss_real: 0.335951358, d_loss_fake: 0.336284012, dcg_loss: 0.385063052 - in Epoch 1/10 - Batch 530/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 535 : d_loss_real: 0.339222252, d_loss_fake: 0.339552194, dcg_loss: 0.388833582 - in Epoch 1/10 - Batch 535/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 540 : d_loss_real: 0.342410922, d_loss_fake: 0.342723817, dcg_loss: 0.392393202 - in Epoch 1/10 - Batch 540/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 545 : d_loss_real: 0.345631838, d_loss_fake: 0.345942676, dcg_loss: 0.395844072 - in Epoch 1/10 - Batch 545/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 550 : d_loss_real: 0.348808378, d_loss_fake: 0.349135995, dcg_loss: 0.399140686 - in Epoch 1/10 - Batch 550/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 555 : d_loss_real: 0.351968259, d_loss_fake: 0.352292776, dcg_loss: 0.402322739 - in Epoch 1/10 - Batch 555/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 560 : d_loss_real: 0.355082780, d_loss_fake: 0.355391800, dcg_loss: 0.405395120 - in Epoch 1/10 - Batch 560/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 565 : d_loss_real: 0.358305365, d_loss_fake: 0.358654261, dcg_loss: 0.408222705 - in Epoch 1/10 - Batch 565/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 570 : d_loss_real: 0.361492246, d_loss_fake: 0.361830503, dcg_loss: 0.410843402 - in Epoch 1/10 - Batch 570/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 575 : d_loss_real: 0.364611208, d_loss_fake: 0.364964396, dcg_loss: 0.413406968 - in Epoch 1/10 - Batch 575/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 580 : d_loss_real: 0.367790580, d_loss_fake: 0.368133873, dcg_loss: 0.415870011 - in Epoch 1/10 - Batch 580/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 585 : d_loss_real: 0.370852143, d_loss_fake: 0.371174723, dcg_loss: 0.418274552 - in Epoch 1/10 - Batch 585/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 590 : d_loss_real: 0.373792410, d_loss_fake: 0.374094665, dcg_loss: 0.420694411 - in Epoch 1/10 - Batch 590/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 595 : d_loss_real: 0.376688451, d_loss_fake: 0.376983345, dcg_loss: 0.423197091 - in Epoch 1/10 - Batch 595/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 600 : d_loss_real: 0.379500240, d_loss_fake: 0.379770905, dcg_loss: 0.425721228 - in Epoch 1/10 - Batch 600/937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# *** time now:  2026-05-30 14:34:37.523584
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 605 : d_loss_real: 0.382177621, d_loss_fake: 0.382479846, dcg_loss: 0.428236037 - in Epoch 1/10 - Batch 605/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 610 : d_loss_real: 0.384760469, d_loss_fake: 0.385019988, dcg_loss: 0.430804193 - in Epoch 1/10 - Batch 610/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 615 : d_loss_real: 0.387295991, d_loss_fake: 0.387546718, dcg_loss: 0.433335155 - in Epoch 1/10 - Batch 615/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# === Iter: 620 : d_loss_real: 0.389757425, d_loss_fake: 0.390016735, dcg_loss: 0.435904950 - in Epoch 1/10 - Batch 620/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 625 : d_loss_real: 0.392242372, d_loss_fake: 0.392485410, dcg_loss: 0.438386321 - in Epoch 1/10 - Batch 625/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 630 : d_loss_real: 0.394633263, d_loss_fake: 0.394867808, dcg_loss: 0.440807998 - in Epoch 1/10 - Batch 630/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 635 : d_loss_real: 0.396974295, d_loss_fake: 0.397222281, dcg_loss: 0.443252832 - in Epoch 1/10 - Batch 635/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 640 : d_loss_real: 0.399328947, d_loss_fake: 0.399580359, dcg_loss: 0.445611894 - in Epoch 1/10 - Batch 640/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 645 : d_loss_real: 0.401673585, d_loss_fake: 0.401893079, dcg_loss: 0.447867781 - in Epoch 1/10 - Batch 645/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 650 : d_loss_real: 0.403933704, d_loss_fake: 0.404166907, dcg_loss: 0.450144231 - in Epoch 1/10 - Batch 650/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 655 : d_loss_real: 0.406197160, d_loss_fake: 0.406417370, dcg_loss: 0.452374309 - in Epoch 1/10 - Batch 655/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 660 : d_loss_real: 0.408472985, d_loss_fake: 0.408690572, dcg_loss: 0.454641074 - in Epoch 1/10 - Batch 660/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# === Iter: 665 : d_loss_real: 0.410661250, d_loss_fake: 0.410867184, dcg_loss: 0.456860721 - in Epoch 1/10 - Batch 665/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 670 : d_loss_real: 0.412839115, d_loss_fake: 0.413052052, dcg_loss: 0.458977818 - in Epoch 1/10 - Batch 670/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 675 : d_loss_real: 0.414995253, d_loss_fake: 0.415206969, dcg_loss: 0.461110711 - in Epoch 1/10 - Batch 675/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 680 : d_loss_real: 0.417071402, d_loss_fake: 0.417276174, dcg_loss: 0.463238209 - in Epoch 1/10 - Batch 680/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 685 : d_loss_real: 0.419103950, d_loss_fake: 0.419310689, dcg_loss: 0.465305537 - in Epoch 1/10 - Batch 685/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 690 : d_loss_real: 0.421118736, d_loss_fake: 0.421321690, dcg_loss: 0.467270166 - in Epoch 1/10 - Batch 690/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 695 : d_loss_real: 0.423110813, d_loss_fake: 0.423306167, dcg_loss: 0.469233155 - in Epoch 1/10 - Batch 695/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 700 : d_loss_real: 0.425037742, d_loss_fake: 0.425222993, dcg_loss: 0.471225977 - in Epoch 1/10 - Batch 700/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 705 : d_loss_real: 0.426944286, d_loss_fake: 0.427139252, dcg_loss: 0.473156869 - in Epoch 1/10 - Batch 705/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 710 : d_loss_real: 0.428851575, d_loss_fake: 0.429043531, dcg_loss: 0.475045264 - in Epoch 1/10 - Batch 710/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 715 : d_loss_real: 0.430712491, d_loss_fake: 0.430913657, dcg_loss: 0.476885617 - in Epoch 1/10 - Batch 715/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 720 : d_loss_real: 0.432578981, d_loss_fake: 0.432754993, dcg_loss: 0.478720427 - in Epoch 1/10 - Batch 720/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 725 : d_loss_real: 0.434392273, d_loss_fake: 0.434569985, dcg_loss: 0.480521381 - in Epoch 1/10 - Batch 725/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 730 : d_loss_real: 0.436193824, d_loss_fake: 0.436376035, dcg_loss: 0.482204437 - in Epoch 1/10 - Batch 730/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 735 : d_loss_real: 0.438045770, d_loss_fake: 0.438235670, dcg_loss: 0.483894646 - in Epoch 1/10 - Batch 735/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 740 : d_loss_real: 0.439879268, d_loss_fake: 0.440066665, dcg_loss: 0.485617191 - in Epoch 1/10 - Batch 740/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 745 : d_loss_real: 0.441742688, d_loss_fake: 0.441924632, dcg_loss: 0.487175852 - in Epoch 1/10 - Batch 745/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 750 : d_loss_real: 0.443546176, d_loss_fake: 0.443716228, dcg_loss: 0.488740325 - in Epoch 1/10 - Batch 750/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# === Iter: 755 : d_loss_real: 0.445310146, d_loss_fake: 0.445483148, dcg_loss: 0.490270138 - in Epoch 1/10 - Batch 755/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 760 : d_loss_real: 0.446933895, d_loss_fake: 0.447101980, dcg_loss: 0.491852701 - in Epoch 1/10 - Batch 760/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# === Iter: 765 : d_loss_real: 0.448526561, d_loss_fake: 0.448682427, dcg_loss: 0.493527234 - in Epoch 1/10 - Batch 765/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9120 : d_loss_real: 0.650970101, d_loss_fake: 0.650970221, dcg_loss: 0.766989052 - in Epoch 10/10 - Batch 687/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 9125 : d_loss_real: 0.650981367, d_loss_fake: 0.650982261, dcg_loss: 0.767022669 - in Epoch 10/10 - Batch 692/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9130 : d_loss_real: 0.650977731, d_loss_fake: 0.650975645, dcg_loss: 0.767065048 - in Epoch 10/10 - Batch 697/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9135 : d_loss_real: 0.650983572, d_loss_fake: 0.650984168, dcg_loss: 0.767112911 - in Epoch 10/10 - Batch 702/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 9140 : d_loss_real: 0.650987625, d_loss_fake: 0.650985658, dcg_loss: 0.767157197 - in Epoch 10/10 - Batch 707/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9145 : d_loss_real: 0.650981724, d_loss_fake: 0.650981307, dcg_loss: 0.767216384 - in Epoch 10/10 - Batch 712/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9150 : d_loss_real: 0.650980115, d_loss_fake: 0.650980651, dcg_loss: 0.767272294 - in Epoch 10/10 - Batch 717/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 9155 : d_loss_real: 0.650990009, d_loss_fake: 0.650989413, dcg_loss: 0.767315984 - in Epoch 10/10 - Batch 722/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9160 : d_loss_real: 0.650992274, d_loss_fake: 0.650993228, dcg_loss: 0.767355978 - in Epoch 10/10 - Batch 727/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 9165 : d_loss_real: 0.650992572, d_loss_fake: 0.650991321, dcg_loss: 0.767385721 - in Epoch 10/10 - Batch 732/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 9170 : d_loss_real: 0.650989771, d_loss_fake: 0.650989532, dcg_loss: 0.767419398 - in Epoch 10/10 - Batch 737/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9175 : d_loss_real: 0.650982141, d_loss_fake: 0.650983512, dcg_loss: 0.767484188 - in Epoch 10/10 - Batch 742/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 9180 : d_loss_real: 0.650986969, d_loss_fake: 0.650987148, dcg_loss: 0.767544746 - in Epoch 10/10 - Batch 747/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9185 : d_loss_real: 0.650986493, d_loss_fake: 0.650990009, dcg_loss: 0.767600477 - in Epoch 10/10 - Batch 752/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9190 : d_loss_real: 0.650989354, d_loss_fake: 0.650989294, dcg_loss: 0.767656147 - in Epoch 10/10 - Batch 757/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 9195 : d_loss_real: 0.650986195, d_loss_fake: 0.650988162, dcg_loss: 0.767683506 - in Epoch 10/10 - Batch 762/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 9200 : d_loss_real: 0.650985301, d_loss_fake: 0.650984526, dcg_loss: 0.767715752 - in Epoch 10/10 - Batch 767/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9205 : d_loss_real: 0.650983691, d_loss_fake: 0.650981367, dcg_loss: 0.767759562 - in Epoch 10/10 - Batch 772/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# === Iter: 9210 : d_loss_real: 0.650983095, d_loss_fake: 0.650983691, dcg_loss: 0.767798781 - in Epoch 10/10 - Batch 777/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9215 : d_loss_real: 0.650984108, d_loss_fake: 0.650982857, dcg_loss: 0.767831922 - in Epoch 10/10 - Batch 782/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# === Iter: 9220 : d_loss_real: 0.650996983, d_loss_fake: 0.650994897, dcg_loss: 0.767890692 - in Epoch 10/10 - Batch 787/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# === Iter: 9225 : d_loss_real: 0.650996804, d_loss_fake: 0.650996923, dcg_loss: 0.767923295 - in Epoch 10/10 - Batch 792/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9230 : d_loss_real: 0.650993407, d_loss_fake: 0.650995314, dcg_loss: 0.767965138 - in Epoch 10/10 - Batch 797/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# === Iter: 9235 : d_loss_real: 0.651000559, d_loss_fake: 0.651000977, dcg_loss: 0.768034160 - in Epoch 10/10 - Batch 802/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 9240 : d_loss_real: 0.651002884, d_loss_fake: 0.651002228, dcg_loss: 0.768074453 - in Epoch 10/10 - Batch 807/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9245 : d_loss_real: 0.650993943, d_loss_fake: 0.650994182, dcg_loss: 0.768133879 - in Epoch 10/10 - Batch 812/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9250 : d_loss_real: 0.650993645, d_loss_fake: 0.650993347, dcg_loss: 0.768172443 - in Epoch 10/10 - Batch 817/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9255 : d_loss_real: 0.650998652, d_loss_fake: 0.650998950, dcg_loss: 0.768209398 - in Epoch 10/10 - Batch 822/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 9260 : d_loss_real: 0.651004016, d_loss_fake: 0.651004970, dcg_loss: 0.768235624 - in Epoch 10/10 - Batch 827/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9265 : d_loss_real: 0.651008308, d_loss_fake: 0.651006579, dcg_loss: 0.768273711 - in Epoch 10/10 - Batch 832/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# === Iter: 9270 : d_loss_real: 0.651006699, d_loss_fake: 0.651005149, dcg_loss: 0.768311024 - in Epoch 10/10 - Batch 837/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9275 : d_loss_real: 0.651002765, d_loss_fake: 0.651003063, dcg_loss: 0.768358588 - in Epoch 10/10 - Batch 842/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9280 : d_loss_real: 0.651002347, d_loss_fake: 0.651001811, dcg_loss: 0.768393695 - in Epoch 10/10 - Batch 847/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9285 : d_loss_real: 0.651002407, d_loss_fake: 0.651001751, dcg_loss: 0.768440366 - in Epoch 10/10 - Batch 852/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9290 : d_loss_real: 0.651006162, d_loss_fake: 0.651007414, dcg_loss: 0.768489063 - in Epoch 10/10 - Batch 857/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9295 : d_loss_real: 0.650997758, d_loss_fake: 0.650996804, dcg_loss: 0.768530309 - in Epoch 10/10 - Batch 862/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9300 : d_loss_real: 0.651004851, d_loss_fake: 0.651006520, dcg_loss: 0.768575668 - in Epoch 10/10 - Batch 867/937
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# *** time now:  2026-05-30 14:46:37.898873
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9305 : d_loss_real: 0.651008546, d_loss_fake: 0.651010633, dcg_loss: 0.768622637 - in Epoch 10/10 - Batch 872/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9310 : d_loss_real: 0.651009083, d_loss_fake: 0.651007533, dcg_loss: 0.768662333 - in Epoch 10/10 - Batch 877/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9315 : d_loss_real: 0.651016891, d_loss_fake: 0.651017904, dcg_loss: 0.768706024 - in Epoch 10/10 - Batch 882/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 9320 : d_loss_real: 0.651026666, d_loss_fake: 0.651024997, dcg_loss: 0.768759787 - in Epoch 10/10 - Batch 887/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 9325 : d_loss_real: 0.651023686, d_loss_fake: 0.651023328, dcg_loss: 0.768791080 - in Epoch 10/10 - Batch 892/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9330 : d_loss_real: 0.651017487, d_loss_fake: 0.651019573, dcg_loss: 0.768832266 - in Epoch 10/10 - Batch 897/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9335 : d_loss_real: 0.651023149, d_loss_fake: 0.651025891, dcg_loss: 0.768897653 - in Epoch 10/10 - Batch 902/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9340 : d_loss_real: 0.651032209, d_loss_fake: 0.651031613, dcg_loss: 0.768950939 - in Epoch 10/10 - Batch 907/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9345 : d_loss_real: 0.651031315, d_loss_fake: 0.651033878, dcg_loss: 0.769004822 - in Epoch 10/10 - Batch 912/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9350 : d_loss_real: 0.651037991, d_loss_fake: 0.651038885, dcg_loss: 0.769057512 - in Epoch 10/10 - Batch 917/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# === Iter: 9355 : d_loss_real: 0.651039064, d_loss_fake: 0.651041448, dcg_loss: 0.769101441 - in Epoch 10/10 - Batch 922/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# === Iter: 9360 : d_loss_real: 0.651043952, d_loss_fake: 0.651044786, dcg_loss: 0.769145191 - in Epoch 10/10 - Batch 927/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# === Iter: 9365 : d_loss_real: 0.651048005, d_loss_fake: 0.651047587, dcg_loss: 0.769182205 - in Epoch 10/10 - Batch 932/937
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# === Iter: 9370 : d_loss_real: 0.651043594, d_loss_fake: 0.651042581, dcg_loss: 0.769224763 - in Epoch 10/10 - Batch 937/937
#
#
#  ~~~ DCGAN trainging ends at 2026-05-30 14:46:44.441699

# %%
print("\n\n ~~~ DCGAN Project is done! Look at images.")
# Out:
#  ~~~ DCGAN Project is done! Look at images.
